# %%
import matplotlib
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
data=pd.read_csv("weather_year.csv")
data
# Out:
#            EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0    2012-3-10                56                 40                24
# 1    2012-3-11                67                 49                30
# 2    2012-3-12                71                 62                53
# 3    2012-3-13                76                 63                50
# 4    2012-3-14                80                 62                44
# 5    2012-3-15                79                 69                58
# 6    2012-3-16                75                 64                52
# 7    2012-3-17                78                 62                46
# 8    2012-3-18                80                 70                59
# 9    2012-3-19                84                 72                59
# 10   2012-3-20                84                 71                58
# 11   2012-3-21                84                 71                57
# ...

# %%
data = data.loc[1:20,["Min TemperatureF","Max TemperatureF", "Max Humidity"]]
data
# Out:
#     Min TemperatureF  Max TemperatureF  Max Humidity
# 1                 30                67            78
# 2                 53                71            90
# 3                 50                76            93
# 4                 44                80            93
# 5                 58                79            90
# 6                 52                75           100
# 7                 46                78           100
# 8                 59                80            93
# 9                 59                84            90
# 10                58                84            78
# 11                57                84            84
# 12                57                81            87
# 13                55                73            97
# 14                46                65           100
# 15                52                69           100
# 16                44                63            96
# 17                38                70            64
# ...

# %%
data["Min TemperatureF"].hist()

# %%
print(data.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  Min TemperatureF &  Max TemperatureF &  Max Humidity \\
# \midrule
# 1  &                30 &                67 &            78 \\
# 2  &                53 &                71 &            90 \\
# 3  &                50 &                76 &            93 \\
# 4  &                44 &                80 &            93 \\
# 5  &                58 &                79 &            90 \\
# 6  &                52 &                75 &           100 \\
# 7  &                46 &                78 &           100 \\
# 8  &                59 &                80 &            93 \\
# 9  &                59 &                84 &            90 \\
# 10 &                58 &                84 &            78 \\
# 11 &                57 &                84 &            84 \\
# 12 &                57 &                81 &            87 \\
# 13 &                55 &                73 &            97 \\
# ...
