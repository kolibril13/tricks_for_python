# %%
from ipywebrtc import CameraStream, ImageRecorder, VideoRecorder, AudioRecorder
import os
# Out:
# CameraStream(constraints={'facing_mode': 'user', 'audio': True, 'video': {'width': 640, 'height': 480}})

# %%
term= """gnome-terminal -e 'sh -c "droidcam; sleep -1"'"""
os.system(term)

# %%
rec0 = ImageRecorder(stream=camera)
rec0
# Out:
# ImageRecorder(image=Image(value=b''), stream=CameraStream(constraints={'facing_mode': 'user', 'audio': True, '…

# %%
import PIL.Image
import PIL.ImageFilter
import PIL.ImageOps
import io
im = PIL.Image.open(io.BytesIO(rec0.image.value))
im = im.filter(PIL.ImageFilter.CONTOUR)
im
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480 at 0x7FC9CD72D320>

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('IvUU8joBb1Q')
