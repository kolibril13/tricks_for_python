# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.version
# Out:
# '3.7.3 (default, Mar 27 2019, 22:11:17) \n[GCC 7.3.0]'

# %%
img= plt.imread("glen.jpg")
plt.imshow(img)

# %%
from PIL import Image, ImageOps
import numpy as np

# %%
img_pil= Image.fromarray(np.uint8(img))
img_pil = ImageOps.equalize(img_pil)
plt.imshow(img_pil)

# %%
img2 = np.asarray(img_pil.ravel)
im2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b62f815be66e> in <module>
# ----> 1 img2 = np.asarray(img_pil.ravel)
#       2 im2
#
# AttributeError: 'Image' object has no attribute 'ravel'
