# %%
from mpl_toolkits import mplot3d
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# %%
# !python --version
# Out:
# Python 3.8.8

# %%
data = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()

# %%
data = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
data = data.T

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()

# %%
data = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
data = data.T.T

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()

# %%
data = np.array([[[1.5, 1], [3, 3]], [[2, 2], [2, 2]]])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()

# %%
data = np.array([[[1.5, 1], [3, 3]], [[2, 2], [2, 2]]])
data = data.T

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()

# %%
data = np.array([[[1, 1], [3, 3]], [[2, 2], [2, 2]]])
data = data.T.T

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = data.nonzero()
ax.scatter(x, y, z, c=data, s=1000 , alpha=1, cmap='bwr')
plt.show()
