# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['figure.dpi'] = 150

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,3*np.pi,1001)
labels = [ r'$\frac{\pi}{2}$','$\pi$',r'$\frac{3\pi}{2}$', '$2\pi$', r'$\frac{5\pi}{2}$', '$3\pi$', r'$\frac{7\pi}{2}$', '$4\pi$' ]
tick_pos= [ (i+1)*np.pi/2 for i in range(0,len(labels))]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 4*np.pi+ 0.3*np.pi)
#plt.plot(x, np.sin(x))
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos, labels , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [rad]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.5,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
#plt.plot(x, np.sin(x))
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [m]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.5,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
#plt.plot(x, np.sin(x))
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r't in [s]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,4*np.pi,1001)
labels = [ r'$\frac{\pi}{2}$','$\pi$',r'$\frac{3\pi}{2}$', '$2\pi$', r'$\frac{5\pi}{2}$', '$3\pi$', r'$\frac{7\pi}{2}$', '$4\pi$' ]
tick_pos= [ (i+1)*np.pi/2 for i in range(0,len(labels))]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 4*np.pi+ 0.3*np.pi)
################
plt.plot(x, 2*np.sin(x), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos, labels , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [rad]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.0,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
################
plt.plot(x, 2*np.sin(2*np.pi*x), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [m]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.0,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
################
plt.plot(x, 3*np.sin(-2*np.pi*x/2), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [m]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
# dell
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.0,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
################
plt.plot(x, 3*np.sin(-2*np.pi*x/2), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r'x in [m]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);
plt.margins()
# Out:
# (0.05, 0.05)

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.0,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
################
plt.plot(x, 3*np.sin(2*np.pi*x), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r't in [s]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,2.0,1001)
tick_pos= [ 0.25*(i+1) for i in range(0,8)]
[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
plt.ylim(-3,3)
plt.xlim(0, 2 +  0.15)
################
plt.plot(x, 2*np.cos(2*np.pi*x*2), lw=3)
plt.yticks(fontsize=20, alpha=0.6);
plt.xticks(tick_pos , fontsize=20, alpha=0.6 );
plt.annotate(r't in [s]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(16,3))

x=np.linspace(0,1,1001)
tick_pos= [ 0, 1]
#[plt.axhline(i, color= "Gray", alpha=0.4 ) for i in range(-2,3)]
#[plt.axvline(i, color= "Gray", alpha=0.4 ) for i in tick_pos]
plt.axhline(0, color= "Black")
#plt.ylim(-3,3)
plt.xlim(0, 1)
#plt.plot(x, np.sin(x))
labels = ["0","L" ]
n=1
lam=4*1/(2*n-1)
plt.plot(x,np.sin(2*np.pi*x/lam), lw= 2, ls= "-", color= "Gray")
n=2
lam=4*1/(2*n-1)
plt.plot(x,np.sin(2*np.pi*x/lam),lw= 2, ls= "--",color= "Gray")
n=3
lam=4*1/(2*n-1)
plt.plot(x,np.sin(2*np.pi*x/lam),lw= 2, ls= ":",color= "Gray")
plt.yticks([],fontsize=20, alpha=0.6);
plt.xticks(tick_pos ,labels=labels ,fontsize=40, alpha=0.6 );
plt.annotate(r'x in [m]',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom',
            fontsize=20);
